# %%
import os
import numpy as np
import pandas as pd
import warnings

from google.colab import drive

warnings.filterwarnings('ignore')
drive.mount("/content/drive")

os.chdir("drive/MyDrive/AI competition/Round 1")
os.listdir()
# Out:
# Mounted at /content/drive
# ['competition_data',
#  '__pycache__',
#  'evaluator.py',
#  'feature EDA.ipynb',
#  'html',
#  'submission',
#  'AutoML Baseline.ipynb',
#  'Evaluator Module.ipynb',
#  'logs.log',
#  'playground.ipynb']

# %%
from evaluator import Evaluator

train_df = pd.read_csv('competition_data/train.csv')
train_df = train_df.drop(["index", "country"], axis=1)
train_df.head()
# Out:
#     Q1   Q2   Q3   Q4   Q5   Q6   Q7   Q8   Q9  Q10  ...  engnat  age  hand  \
# 0  1.0  5.0  5.0  5.0  1.0  4.0  5.0  5.0  1.0  3.0  ...     1.0   20   2.0
# 1  4.0  4.0  4.0  4.0  4.0  5.0  4.0  4.0  3.0  3.0  ...     1.0   49   1.0
# 2  4.0  5.0  5.0  4.0  3.0  5.0  5.0  5.0  4.0  4.0  ...     2.0   43   1.0
# 3  4.0  4.0  4.0  2.0  4.0  3.0  3.0  5.0  3.0  4.0  ...     1.0   17   2.0
# 4  4.0  4.0  4.0  4.0  3.0  3.0  4.0  2.0  3.0  4.0  ...     2.0   18   2.0
#
#    religion  orientation  voted  married  familysize  ASD  nerdiness
# 0      12.0          4.0    2.0      1.0         4.0  2.0          1
# 1       2.0          1.0    1.0      2.0         4.0  2.0          1
# 2       2.0          2.0    2.0      3.0         4.0  2.0          1
# 3       1.0          1.0    2.0      1.0         2.0  2.0          1
# 4      12.0          1.0    2.0      1.0         1.0  2.0          0
#
# [5 rows x 68 columns]

# %%
from xgboost import XGBClassifier

xgb_clf = XGBClassifier(
    n_estimators=1000,
)

Evaluator(
    model=xgb_clf,
    train_df=train_df,
    n_splits=5,
).evaluate()
# Out:
# ** Fold 1 **
# accuracy 0.7416666666666667
# precision 0.7501410039481106
# recall 0.8002406738868832
# f1-score 0.7743813682678312
# roc_auc 0.7345747465099588
# mae 0.25833333333333336
#
# ** Fold 2 **
# accuracy 0.7526666666666667
# precision 0.7642369020501139
# recall 0.8035928143712575
# f1-score 0.783420899007589
# roc_auc 0.7461573094412679
# mae 0.24733333333333332
#
# ** Fold 3 **
# accuracy 0.7456666666666667
# precision 0.7527568195008706
# recall 0.7937576499388005
# f1-score 0.7727137324992553
# roc_auc 0.7409491031538804
# mae 0.25433333333333336
#
# ** Fold 4 **
# accuracy 0.7543333333333333
# precision 0.7683908045977011
# recall 0.8001196888090963
# f1-score 0.7839343301084726
# roc_auc 0.7484420866919825
# mae 0.24566666666666667
#
# ** Fold 5 **
# accuracy 0.7393333333333333
# precision 0.748314606741573
# recall 0.7995198079231692
# f1-score 0.7730702263493906
# roc_auc 0.7318438619825741
# mae 0.26066666666666666
#
# ** total **
# accuracy 0.7467333333333334
# precision 0.7567680273676738
# recall 0.7994461269858414
# f1-score 0.7775041112465078
# roc_auc 0.7403934215559327
# mae 0.25326666666666664
