# %%
import os
import numpy as np
import pandas as pd
import warnings

from google.colab import drive

warnings.filterwarnings('ignore')
drive.mount("/content/drive")

os.chdir("drive/MyDrive/AI competition/Round 1")
os.listdir()
# Out:
# Mounted at /content/drive
# ['competition_data',
#  '__pycache__',
#  'html',
#  'submission',
#  'logs.log',
#  'playground.ipynb',
#  'AutoML Baseline.ipynb',
#  'Evaluator Module.ipynb',
#  '2022-08-04 feature EDA.ipynb',
#  "2022-08-05 LGB_train(hyeonbin's parameter tuning).ipynb",
#  'model compare.ipynb',
#  'Optuna Optimization.ipynb',
#  'evaluator.py',
#  '2022-08-06 Optimize ET.ipynb',
#  '2022-08-06 Regressor model compare.ipynb']

# %%
# !pip install optuna

# %%
from evaluator import Evaluator, Model

train_df = pd.read_csv('competition_data/train.csv')
test_df = pd.read_csv("competition_data/test.csv")
submission_df = pd.read_csv("competition_data/sample_submission.csv")
train_df.head()
# Out:
#    index   Q1   Q2   Q3   Q4   Q5   Q6   Q7   Q8   Q9  ...  engnat  age  hand  \
# 0      0  1.0  5.0  5.0  5.0  1.0  4.0  5.0  5.0  1.0  ...     1.0   20   2.0
# 1      1  4.0  4.0  4.0  4.0  4.0  5.0  4.0  4.0  3.0  ...     1.0   49   1.0
# 2      2  4.0  5.0  5.0  4.0  3.0  5.0  5.0  5.0  4.0  ...     2.0   43   1.0
# 3      3  4.0  4.0  4.0  2.0  4.0  3.0  3.0  5.0  3.0  ...     1.0   17   2.0
# 4      4  4.0  4.0  4.0  4.0  3.0  3.0  4.0  2.0  3.0  ...     2.0   18   2.0
#
#    religion  orientation  voted  married  familysize  ASD  nerdiness
# 0      12.0          4.0    2.0      1.0         4.0  2.0          1
# 1       2.0          1.0    1.0      2.0         4.0  2.0          1
# 2       2.0          2.0    2.0      3.0         4.0  2.0          1
# 3       1.0          1.0    2.0      1.0         2.0  2.0          1
# 4      12.0          1.0    2.0      1.0         1.0  2.0          0
#
# [5 rows x 70 columns]

# %%
evaluator = Evaluator(
    **Model(train_df, "lgbm", "rgr").get_model(),
)
evaluator.run()
# Out:
#       accuracy  precision    recall  f1-score   roc_auc       mae  train_acc
# fold
# 1     0.743982   0.750899  0.814031  0.781192  0.818549  0.347802        NaN
# 2     0.755861   0.749740  0.828457  0.787135  0.827119  0.345362        NaN
# 3     0.746171   0.747315  0.821248  0.782539  0.822338  0.348606        NaN
# 4     0.751485   0.775446  0.801084  0.788057  0.817048  0.346084        NaN
# mean  0.749375   0.755850  0.816205  0.784731  0.821263  0.346963   0.850813

# %%
submission = evaluator.make_submission(test_df, submission_df)
submission.to_csv("submission/2022-08-07_LGBM-rgr-base.csv", index=False)

# %%
evaluator = Evaluator(
    **Model("xgb", "rgr").get_model(),
    train_df = train_df,
)
evaluator.run()
# Out:
# 0it [00:00, ?it/s]
# [03:40:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:40:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:41:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:41:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:41:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#       accuracy  precision    recall  f1-score   roc_auc       mae  train_acc
# fold
# 1     0.731791   0.738313  0.809020  0.772051  0.801329  0.365075        NaN
# 2     0.735542   0.727549  0.822719  0.772213  0.809880  0.363129        NaN
# 3     0.733979   0.735772  0.813940  0.772885  0.802653  0.367916        NaN
# 4     0.737418   0.758355  0.799458  0.778364  0.800628  0.365988        NaN
# mean  0.734683   0.739997  0.811284  0.773878  0.803622  0.365527   0.759456

# %%
evaluator = Evaluator(
    **Model(train_df, "rf", "rgr").get_model(),
)
evaluator.run()
# Out:
#       accuracy  precision    recall  f1-score   roc_auc       mae  train_acc
# fold
# 1     0.776805   0.788072  0.824053  0.805661  0.864448  0.324051        NaN
# 2     0.779619   0.773446  0.842226  0.806372  0.865717  0.328237        NaN
# 3     0.771491   0.775210  0.829680  0.801520  0.851382  0.333698        NaN
# 4     0.778056   0.799472  0.821138  0.810160  0.856909  0.328731        NaN
# mean  0.776493   0.784050  0.829274  0.805929  0.859614  0.328679        1.0

# %%
submission = evaluator.make_submission(test_df, submission_df)
submission.to_csv("submission/2022-08-07_RF-rgr-base.csv", index=False)

# %%
evaluator = Evaluator(
    **Model(train_df, "et", "rgr").get_model(),
)
evaluator.run()
# Out:
#       accuracy  precision    recall  f1-score   roc_auc       mae  train_acc
# fold
# 1     0.778993   0.791957  0.822383  0.806883  0.865811  0.293651        NaN
# 2     0.779931   0.783415  0.823867  0.803132  0.873052  0.295424        NaN
# 3     0.772116   0.777191  0.827431  0.801525  0.863782  0.301135        NaN
# 4     0.775867   0.800319  0.814634  0.807413  0.866085  0.294945        NaN
# mean  0.776727   0.788221  0.822079  0.804738  0.867183  0.296289        1.0

# %%
submission = evaluator.make_submission(test_df, submission_df)
submission.to_csv("submission/2022-08-07_ET-rgr-base.csv", index=False)

# %% [markdown]
# ### with params

# %%
## v0.4
params = {
  "objective": "binary",
  'metric': 'auc', 
  "n_estimators": 500,
  'learning_rate': 0.026332779906149555,
  'num_leaves': 955,
  'reg_alpha': 6.90331310095056e-08,
  'reg_lambda': 2.30837413695962e-06,
  'feature_fraction': 0.4, 
  'bagging_fraction': 0.8823839979334422, 
  'bagging_freq': 5, 
  'min_child_samples': 5,
}
evaluator = Evaluator(
    **Model("lgbm", "rgr", **params).get_model(),
    train_df = train_df,
)
evaluator.run()
# Out:
# 0it [00:00, ?it/s]
#       accuracy  precision    recall  f1-score   roc_auc       mae  train_acc
# fold
# 1     0.782745   0.783325  0.847439  0.814121  0.875778  0.227949        NaN
# 2     0.790247   0.776860  0.862880  0.817613  0.879281  0.228256        NaN
# 3     0.780556   0.772658  0.857785  0.812999  0.872667  0.234034        NaN
# 4     0.791497   0.800817  0.849864  0.824612  0.873457  0.226965        NaN
# mean  0.786261   0.783415  0.854492  0.817337  0.875296  0.229301        1.0

# %%
## v0.2
params = {
    'objective': 'binary', 
    "n_estimators": 1000,
    'learning_rate': 0.01, 
    'random_state': 42, 
    'metric': 'auc', 
    'verbose': -1, 
    'feature_pre_filter': False, 
    'lambda_l1': 1.001449223665896e-08, 
    'lambda_l2': 4.805472362670594e-05, 
    'num_leaves': 243, 
    'feature_fraction': 0.4, 
    'bagging_fraction': 0.8823839979334422, 
    'bagging_freq': 5, 
    'min_child_samples': 5
}
evaluator = Evaluator(
    **Model("lgbm", "rgr", **params).get_model(),
    train_df = train_df,
)
evaluator.run()
# Out:
# 0it [00:00, ?it/s]
#       accuracy  precision    recall  f1-score   roc_auc       mae  train_acc
# fold
# 1     0.783057   0.788482  0.838530  0.812736  0.872587  0.266810        NaN
# 2     0.788059   0.777199  0.856569  0.814956  0.876468  0.268337        NaN
# 3     0.783057   0.779495  0.850478  0.813441  0.866985  0.274583        NaN
# 4     0.792123   0.806653  0.841192  0.823561  0.864463  0.269379        NaN
# mean  0.786574   0.787957  0.846692  0.816173  0.870126  0.269777        1.0
