# %%
import os
import numpy as np
import pandas as pd
import warnings

from google.colab import drive

warnings.filterwarnings('ignore')
drive.mount("/content/drive")

os.chdir("drive/MyDrive/competition/2022-AI-competition-Round1") # Local Path
os.listdir()
# Out:
# Mounted at /content/drive
# ['competition_data',
#  'html',
#  'submission',
#  'playground.ipynb',
#  'AutoML Baseline.ipynb',
#  'Evaluator Module.ipynb',
#  '2022-08-04 feature EDA.ipynb',
#  "2022-08-05 LGB_train(hyeonbin's parameter tuning).ipynb",
#  'model compare.ipynb',
#  'Optuna Optimization.ipynb',
#  '2022-08-06 Optimize ET.ipynb',
#  '2022-08-06 Regressor model compare.ipynb',
#  'catboost_info',
#  'evaluator',
#  '.git',
#  '.gitignore',
#  'README.md',
#  'Updated CLF.ipynb',
#  '2022-08-17 Ensemble Module.ipynb',
#  '2022-08-11 Models(XGB_ET) Optimization.ipynb',
#  'GitHub Connection.ipynb']

# %%
# !pip install -r evaluator/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1.0.6-cp37-none-manylinux1_x86_64.whl (76.6 MB)
#      |████████████████████████████████| 76.6 MB 92 kB/s
# Collecting optuna
#   Downloading optuna-2.10.1-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 75.2 MB/s
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from catboost->-r evaluator/requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from catboost->-r evaluator/requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from catboost->-r evaluator/requirements.txt (line 1)) (1.3.5)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (from catboost->-r evaluator/requirements.txt (line 1)) (0.10.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from catboost->-r evaluator/requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from catboost->-r evaluator/requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from catboost->-r evaluator/requirements.txt (line 1)) (3.2.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->catboost->-r evaluator/requirements.txt (line 1)) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->catboost->-r evaluator/requirements.txt (line 1)) (2.8.2)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 11.5 MB/s
# Collecting alembic
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 74.6 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna->-r evaluator/requirements.txt (line 2)) (4.64.0)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna->-r evaluator/requirements.txt (line 2)) (21.3)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna->-r evaluator/requirements.txt (line 2)) (1.4.40)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna->-r evaluator/requirements.txt (line 2)) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna->-r evaluator/requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna->-r evaluator/requirements.txt (line 2)) (4.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna->-r evaluator/requirements.txt (line 2)) (1.1.2)
# Collecting Mako
#   Downloading Mako-1.2.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.4 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna->-r evaluator/requirements.txt (line 2)) (5.9.0)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 7.9 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna->-r evaluator/requirements.txt (line 2)) (3.3.0)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.2-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 62.8 MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.10.0-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 68.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna->-r evaluator/requirements.txt (line 2)) (4.1.1)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna->-r evaluator/requirements.txt (line 2)) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna->-r evaluator/requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna->-r evaluator/requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna->-r evaluator/requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->catboost->-r evaluator/requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->catboost->-r evaluator/requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly->catboost->-r evaluator/requirements.txt (line 1)) (8.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=88ea312da41a3cc0ef779f3d9348820093e3138881b434a48251adc375357382
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna, catboost
# Successfully installed Mako-1.2.1 alembic-1.8.1 autopage-0.5.1 catboost-1.0.6 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.2 colorlog-6.6.0 optuna-2.10.1 pbr-5.10.0 pyperclip-1.8.2 stevedore-3.5.0

# %%
from evaluator.evaluator import Evaluator, Model

train_df = pd.read_csv('competition_data/train.csv')
test_df = pd.read_csv("competition_data/test.csv")
submission_df = pd.read_csv("competition_data/sample_submission.csv")

# %%
from sklearn.ensemble import VotingRegressor

# %%
lgbm_params = {
  "objective": "binary",
  'metric': 'auc', 
  "n_estimators": 500,
  'learning_rate': 0.026332779906149555,
  'num_leaves': 955,
  'reg_alpha': 6.90331310095056e-08,
  'reg_lambda': 2.30837413695962e-06,
  'feature_fraction': 0.4, 
  'bagging_fraction': 0.8823839979334422, 
  'bagging_freq': 5, 
  'min_child_samples': 5,
}
lgbm_model = Model(
    train_df, "lgbm", "rgr", **lgbm_params
).get_model()['model']

# %%
et_params = {
	'n_estimators': 292, 
	'max_depth': 45, 
	'min_samples_split': 2, 
	'min_samples_leaf': 1, 
	'max_features': 0.729627795893577
}
et_model = Model(
    train_df, "et", "rgr", **et_params
).get_model()['model']

# %%
xgb_params = {
    "objective": "reg:squarederror",
    "average": "micro",
    'n_estimators': 746, 
    'learning_rate': 0.0181863245309935, 
    'gamma': 0, 
    'max_depth': 11, 
    'lambda': 1, 
    'alpha': 4, 
    'subsample': 0.7231465475519483
}
xgb_model = Model(
    train_df, "xgb", "rgr", **xgb_params
).get_model()['model']

# %%
cat_params = {
  'learning_rate': 0.01001831305173243,
  'bagging_temperature': 5.20036760425302,
  'n_estimators': 120, 
  'max_depth': 16,
  'random_strength': 0,
  'colsample_bylevel': 0.984260923537832,
  'l2_leaf_reg': 1.0732827610812122e-05,
  'min_child_samples': 100,
  'max_bin': 302,
  'od_type': 'Iter'
}
cat_model = Model(
    train_df, "cat", "rgr", **cat_params
).get_model()['model']

# %%
ensemble_model = VotingRegressor([
    ('lgbm', lgbm_model), 
    ('et', et_model), 
    ('xgb', xgb_model),
    ('cat', cat_model),
])

# %%
ensemble_model
# Out:
# VotingRegressor(estimators=[('lgbm',
#                              LGBMRegressor(bagging_fraction=0.8823839979334422,
#                                            bagging_freq=5, feature_fraction=0.4,
#                                            learning_rate=0.026332779906149555,
#                                            metric='auc', min_child_samples=5,
#                                            n_estimators=500, num_leaves=955,
#                                            objective='binary',
#                                            reg_alpha=6.90331310095056e-08,
#                                            reg_lambda=2.30837413695962e-06)),
#                             ('et',
#                              ExtraTreesRegressor(max_depth=45,
#                                                  max_features=0.729627795893577,
#                                                  n_estimators=292)),
#                             ('xgb',
#                              XGBRegressor(alpha=4, average='micro', lambda=1,
#                                           learning_rate=0.0181863245309935,
#                                           max_depth=11, n_estimators=746,
#                                           objective='reg:squarederror',
#                                           subsample=0.7231465475519483)),
#                             ('cat',
#                              <catboost.core.CatBoostRegressor object at 0x7ff34988c3d0>)])

# %%
evaluator = Evaluator(
    train_df=train_df, 
    model = ensemble_model,
    model_name = "ensemble",
    model_type = "rgr"
)

# %%
evaluator.run()
# Out:
# 0:	learn: 0.4921645	total: 2.5s	remaining: 4m 57s
# 1:	learn: 0.4878246	total: 4.93s	remaining: 4m 50s
# 2:	learn: 0.4835046	total: 7.34s	remaining: 4m 46s
# 3:	learn: 0.4793689	total: 9.78s	remaining: 4m 43s
# 4:	learn: 0.4751071	total: 12.2s	remaining: 4m 41s
# 5:	learn: 0.4709259	total: 14.7s	remaining: 4m 38s
# 6:	learn: 0.4668351	total: 17.1s	remaining: 4m 35s
# 7:	learn: 0.4627988	total: 19.4s	remaining: 4m 31s
# 8:	learn: 0.4587634	total: 21.8s	remaining: 4m 28s
# 9:	learn: 0.4548218	total: 24.3s	remaining: 4m 27s
# 10:	learn: 0.4507604	total: 26.7s	remaining: 4m 24s
# 11:	learn: 0.4468384	total: 29.3s	remaining: 4m 23s
# 12:	learn: 0.4428657	total: 31.9s	remaining: 4m 22s
# 13:	learn: 0.4389955	total: 34.3s	remaining: 4m 19s
# 14:	learn: 0.4351079	total: 36.7s	remaining: 4m 17s
# 15:	learn: 0.4313491	total: 39.2s	remaining: 4m 14s
# 16:	learn: 0.4277602	total: 41.7s	remaining: 4m 12s
# 17:	learn: 0.4240642	total: 44.1s	remaining: 4m 10s
# 18:	learn: 0.4204291	total: 46.6s	remaining: 4m 7s
# 19:	learn: 0.4167167	total: 49s	remaining: 4m 5s
# 20:	learn: 0.4130367	total: 51.5s	remaining: 4m 2s
# 21:	learn: 0.4094576	total: 55.2s	remaining: 4m 5s
# 22:	learn: 0.4060154	total: 57.9s	remaining: 4m 4s
# 23:	learn: 0.4024493	total: 1m	remaining: 4m 1s
# 24:	learn: 0.3991380	total: 1m 2s	remaining: 3m 58s
# 25:	learn: 0.3956580	total: 1m 5s	remaining: 3m 55s
# 26:	learn: 0.3922021	total: 1m 7s	remaining: 3m 53s
# 27:	learn: 0.3888544	total: 1m 10s	remaining: 3m 50s
# 28:	learn: 0.3855215	total: 1m 12s	remaining: 3m 47s
# 29:	learn: 0.3821998	total: 1m 15s	remaining: 3m 44s
# 30:	learn: 0.3788733	total: 1m 17s	remaining: 3m 42s
# 31:	learn: 0.3756111	total: 1m 19s	remaining: 3m 39s
# 32:	learn: 0.3723563	total: 1m 22s	remaining: 3m 37s
# 33:	learn: 0.3691802	total: 1m 24s	remaining: 3m 34s
# 34:	learn: 0.3659782	total: 1m 27s	remaining: 3m 31s
# 35:	learn: 0.3627932	total: 1m 29s	remaining: 3m 29s
# 36:	learn: 0.3597225	total: 1m 32s	remaining: 3m 26s
# 37:	learn: 0.3566623	total: 1m 34s	remaining: 3m 23s
# 38:	learn: 0.3536817	total: 1m 36s	remaining: 3m 21s
# 39:	learn: 0.3505803	total: 1m 39s	remaining: 3m 18s
# 40:	learn: 0.3476520	total: 1m 41s	remaining: 3m 15s
# 41:	learn: 0.3446150	total: 1m 44s	remaining: 3m 13s
# 42:	learn: 0.3417458	total: 1m 46s	remaining: 3m 10s
# 43:	learn: 0.3389154	total: 1m 48s	remaining: 3m 8s
# 44:	learn: 0.3361117	total: 1m 51s	remaining: 3m 5s
# 45:	learn: 0.3331582	total: 1m 53s	remaining: 3m 2s
# 46:	learn: 0.3304225	total: 1m 56s	remaining: 3m
# 47:	learn: 0.3276149	total: 1m 58s	remaining: 2m 57s
# 48:	learn: 0.3248137	total: 2m	remaining: 2m 55s
# 49:	learn: 0.3219578	total: 2m 3s	remaining: 2m 52s
# 50:	learn: 0.3191438	total: 2m 5s	remaining: 2m 50s
# 51:	learn: 0.3164757	total: 2m 8s	remaining: 2m 47s
# 52:	learn: 0.3138374	total: 2m 10s	remaining: 2m 44s
# 53:	learn: 0.3111541	total: 2m 12s	remaining: 2m 42s
# 54:	learn: 0.3084949	total: 2m 15s	remaining: 2m 39s
# 55:	learn: 0.3058494	total: 2m 17s	remaining: 2m 37s
# 56:	learn: 0.3032444	total: 2m 20s	remaining: 2m 34s
# 57:	learn: 0.3005826	total: 2m 22s	remaining: 2m 32s
# 58:	learn: 0.2980997	total: 2m 24s	remaining: 2m 29s
# 59:	learn: 0.2955547	total: 2m 27s	remaining: 2m 27s
# 60:	learn: 0.2930803	total: 2m 29s	remaining: 2m 24s
# 61:	learn: 0.2906201	total: 2m 32s	remaining: 2m 22s
# 62:	learn: 0.2881117	total: 2m 34s	remaining: 2m 19s
# 63:	learn: 0.2858338	total: 2m 36s	remaining: 2m 17s
# 64:	learn: 0.2833807	total: 2m 39s	remaining: 2m 14s
# 65:	learn: 0.2809277	total: 2m 41s	remaining: 2m 12s
# 66:	learn: 0.2785820	total: 2m 44s	remaining: 2m 9s
# 67:	learn: 0.2762031	total: 2m 46s	remaining: 2m 7s
# 68:	learn: 0.2738305	total: 2m 48s	remaining: 2m 4s
# 69:	learn: 0.2716117	total: 2m 51s	remaining: 2m 2s
# 70:	learn: 0.2693371	total: 2m 53s	remaining: 1m 59s
# 71:	learn: 0.2671103	total: 2m 56s	remaining: 1m 57s
# 72:	learn: 0.2649907	total: 2m 58s	remaining: 1m 54s
# 73:	learn: 0.2627726	total: 3m	remaining: 1m 52s
# 74:	learn: 0.2605513	total: 3m 3s	remaining: 1m 50s
# 75:	learn: 0.2583678	total: 3m 5s	remaining: 1m 47s
# 76:	learn: 0.2562003	total: 3m 8s	remaining: 1m 45s
# 77:	learn: 0.2540550	total: 3m 10s	remaining: 1m 42s
# 78:	learn: 0.2520468	total: 3m 13s	remaining: 1m 40s
# 79:	learn: 0.2499837	total: 3m 15s	remaining: 1m 37s
# 80:	learn: 0.2479309	total: 3m 19s	remaining: 1m 35s
# 81:	learn: 0.2458693	total: 3m 21s	remaining: 1m 33s
# 82:	learn: 0.2438269	total: 3m 24s	remaining: 1m 31s
# 83:	learn: 0.2419659	total: 3m 26s	remaining: 1m 28s
# 84:	learn: 0.2400796	total: 3m 29s	remaining: 1m 26s
# 85:	learn: 0.2381377	total: 3m 31s	remaining: 1m 23s
# 86:	learn: 0.2362732	total: 3m 34s	remaining: 1m 21s
# 87:	learn: 0.2343679	total: 3m 36s	remaining: 1m 18s
# 88:	learn: 0.2325048	total: 3m 38s	remaining: 1m 16s
# 89:	learn: 0.2305237	total: 3m 41s	remaining: 1m 13s
# 90:	learn: 0.2286494	total: 3m 43s	remaining: 1m 11s
# 91:	learn: 0.2267190	total: 3m 45s	remaining: 1m 8s
# 92:	learn: 0.2248039	total: 3m 48s	remaining: 1m 6s
# 93:	learn: 0.2230236	total: 3m 50s	remaining: 1m 3s
# 94:	learn: 0.2212379	total: 3m 53s	remaining: 1m 1s
# 95:	learn: 0.2193656	total: 3m 55s	remaining: 58.8s
# 96:	learn: 0.2175820	total: 3m 57s	remaining: 56.4s
# 97:	learn: 0.2157249	total: 4m	remaining: 53.9s
# 98:	learn: 0.2138761	total: 4m 2s	remaining: 51.5s
# 99:	learn: 0.2121754	total: 4m 5s	remaining: 49s
# 100:	learn: 0.2105457	total: 4m 7s	remaining: 46.6s
# 101:	learn: 0.2087639	total: 4m 9s	remaining: 44.1s
# 102:	learn: 0.2070661	total: 4m 12s	remaining: 41.6s
# 103:	learn: 0.2053294	total: 4m 14s	remaining: 39.2s
# 104:	learn: 0.2036560	total: 4m 17s	remaining: 36.7s
# 105:	learn: 0.2019565	total: 4m 19s	remaining: 34.3s
# 106:	learn: 0.2003010	total: 4m 21s	remaining: 31.8s
# 107:	learn: 0.1987593	total: 4m 24s	remaining: 29.4s
# 108:	learn: 0.1971903	total: 4m 26s	remaining: 26.9s
# 109:	learn: 0.1955834	total: 4m 29s	remaining: 24.5s
# 110:	learn: 0.1938990	total: 4m 31s	remaining: 22s
# 111:	learn: 0.1924205	total: 4m 34s	remaining: 19.6s
# 112:	learn: 0.1908774	total: 4m 36s	remaining: 17.1s
# 113:	learn: 0.1893027	total: 4m 38s	remaining: 14.7s
# 114:	learn: 0.1878144	total: 4m 41s	remaining: 12.2s
# 115:	learn: 0.1863056	total: 4m 43s	remaining: 9.78s
# 116:	learn: 0.1848062	total: 4m 46s	remaining: 7.34s
# 117:	learn: 0.1833113	total: 4m 48s	remaining: 4.89s
# 118:	learn: 0.1818675	total: 4m 50s	remaining: 2.44s
# 119:	learn: 0.1803517	total: 4m 53s	remaining: 0us
# 0:	learn: 0.4913473	total: 2.48s	remaining: 4m 55s
# 1:	learn: 0.4869707	total: 4.94s	remaining: 4m 51s
# 2:	learn: 0.4827065	total: 7.41s	remaining: 4m 48s
# 3:	learn: 0.4786069	total: 9.84s	remaining: 4m 45s
# 4:	learn: 0.4744658	total: 12.3s	remaining: 4m 42s
# 5:	learn: 0.4703285	total: 18.9s	remaining: 6m
# 6:	learn: 0.4662738	total: 26.7s	remaining: 7m 10s
# 7:	learn: 0.4622892	total: 31.2s	remaining: 7m 16s
# 8:	learn: 0.4582864	total: 33.7s	remaining: 6m 55s
# 9:	learn: 0.4543372	total: 36.3s	remaining: 6m 38s
# 10:	learn: 0.4503479	total: 38.8s	remaining: 6m 24s
# 11:	learn: 0.4464439	total: 41.4s	remaining: 6m 12s
# 12:	learn: 0.4426285	total: 43.9s	remaining: 6m 1s
# 13:	learn: 0.4390683	total: 46.4s	remaining: 5m 51s
# 14:	learn: 0.4353053	total: 48.9s	remaining: 5m 42s
# 15:	learn: 0.4316057	total: 51.4s	remaining: 5m 34s
# 16:	learn: 0.4279021	total: 54s	remaining: 5m 27s
# 17:	learn: 0.4241854	total: 56.5s	remaining: 5m 20s
# 18:	learn: 0.4204928	total: 59s	remaining: 5m 13s
# 19:	learn: 0.4169529	total: 1m 1s	remaining: 5m 7s
# 20:	learn: 0.4134871	total: 1m 4s	remaining: 5m 2s
# 21:	learn: 0.4100135	total: 1m 6s	remaining: 4m 56s
# 22:	learn: 0.4066106	total: 1m 8s	remaining: 4m 50s
# 23:	learn: 0.4032711	total: 1m 11s	remaining: 4m 45s
# 24:	learn: 0.3998583	total: 1m 14s	remaining: 4m 41s
# 25:	learn: 0.3965715	total: 1m 16s	remaining: 4m 36s
# 26:	learn: 0.3931963	total: 1m 19s	remaining: 4m 33s
# 27:	learn: 0.3898065	total: 1m 23s	remaining: 4m 33s
# 28:	learn: 0.3865289	total: 1m 25s	remaining: 4m 29s
# 29:	learn: 0.3832474	total: 1m 28s	remaining: 4m 24s
# 30:	learn: 0.3799914	total: 1m 30s	remaining: 4m 20s
# 31:	learn: 0.3767070	total: 1m 33s	remaining: 4m 16s
# 32:	learn: 0.3735524	total: 1m 35s	remaining: 4m 12s
# 33:	learn: 0.3703734	total: 1m 38s	remaining: 4m 8s
# 34:	learn: 0.3673462	total: 1m 40s	remaining: 4m 5s
# 35:	learn: 0.3642594	total: 1m 43s	remaining: 4m 1s
# 36:	learn: 0.3611955	total: 1m 46s	remaining: 3m 57s
# 37:	learn: 0.3581332	total: 1m 48s	remaining: 3m 54s
# 38:	learn: 0.3550267	total: 1m 50s	remaining: 3m 50s
# 39:	learn: 0.3521689	total: 1m 53s	remaining: 3m 47s
# 40:	learn: 0.3492992	total: 1m 56s	remaining: 3m 43s
# 41:	learn: 0.3463776	total: 1m 58s	remaining: 3m 40s
# 42:	learn: 0.3433744	total: 2m 1s	remaining: 3m 36s
# 43:	learn: 0.3405249	total: 2m 3s	remaining: 3m 33s
# 44:	learn: 0.3377001	total: 2m 6s	remaining: 3m 30s
# 45:	learn: 0.3349233	total: 2m 8s	remaining: 3m 26s
# 46:	learn: 0.3322541	total: 2m 10s	remaining: 3m 23s
# 47:	learn: 0.3293783	total: 2m 13s	remaining: 3m 20s
# 48:	learn: 0.3265447	total: 2m 15s	remaining: 3m 17s
# 49:	learn: 0.3237256	total: 2m 18s	remaining: 3m 13s
# 50:	learn: 0.3210156	total: 2m 21s	remaining: 3m 10s
# 51:	learn: 0.3183821	total: 2m 23s	remaining: 3m 7s
# 52:	learn: 0.3157931	total: 2m 26s	remaining: 3m 4s
# 53:	learn: 0.3130623	total: 2m 28s	remaining: 3m 1s
# 54:	learn: 0.3103996	total: 2m 31s	remaining: 2m 58s
# 55:	learn: 0.3077911	total: 2m 33s	remaining: 2m 55s
# 56:	learn: 0.3051330	total: 2m 36s	remaining: 2m 52s
# 57:	learn: 0.3025801	total: 2m 38s	remaining: 2m 49s
# 58:	learn: 0.3000504	total: 2m 41s	remaining: 2m 46s
# 59:	learn: 0.2975166	total: 2m 43s	remaining: 2m 43s
# 60:	learn: 0.2950080	total: 2m 46s	remaining: 2m 40s
# 61:	learn: 0.2925624	total: 2m 48s	remaining: 2m 37s
# 62:	learn: 0.2900554	total: 2m 51s	remaining: 2m 35s
# 63:	learn: 0.2877214	total: 2m 53s	remaining: 2m 32s
# 64:	learn: 0.2853342	total: 2m 56s	remaining: 2m 29s
# 65:	learn: 0.2829396	total: 2m 58s	remaining: 2m 26s
# 66:	learn: 0.2806379	total: 3m 1s	remaining: 2m 23s
# 67:	learn: 0.2782966	total: 3m 3s	remaining: 2m 20s
# 68:	learn: 0.2760072	total: 3m 6s	remaining: 2m 17s
# 69:	learn: 0.2737002	total: 3m 8s	remaining: 2m 14s
# 70:	learn: 0.2713305	total: 3m 11s	remaining: 2m 12s
# 71:	learn: 0.2691435	total: 3m 13s	remaining: 2m 9s
# 72:	learn: 0.2668986	total: 3m 16s	remaining: 2m 6s
# 73:	learn: 0.2646264	total: 3m 18s	remaining: 2m 3s
# 74:	learn: 0.2623904	total: 3m 21s	remaining: 2m
# 75:	learn: 0.2601453	total: 3m 23s	remaining: 1m 57s
# 76:	learn: 0.2580041	total: 3m 26s	remaining: 1m 55s
# 77:	learn: 0.2558429	total: 3m 28s	remaining: 1m 52s
# 78:	learn: 0.2537402	total: 3m 31s	remaining: 1m 49s
# 79:	learn: 0.2516344	total: 3m 33s	remaining: 1m 46s
# 80:	learn: 0.2495837	total: 3m 36s	remaining: 1m 44s
# 81:	learn: 0.2474612	total: 3m 38s	remaining: 1m 41s
# 82:	learn: 0.2454476	total: 3m 41s	remaining: 1m 38s
# 83:	learn: 0.2434242	total: 3m 45s	remaining: 1m 36s
# 84:	learn: 0.2413743	total: 3m 47s	remaining: 1m 33s
# 85:	learn: 0.2393984	total: 3m 50s	remaining: 1m 31s
# 86:	learn: 0.2374530	total: 3m 52s	remaining: 1m 28s
# 87:	learn: 0.2355004	total: 3m 55s	remaining: 1m 25s
# 88:	learn: 0.2337406	total: 3m 57s	remaining: 1m 22s
# 89:	learn: 0.2318841	total: 4m	remaining: 1m 20s
# 90:	learn: 0.2299818	total: 4m 2s	remaining: 1m 17s
# 91:	learn: 0.2281360	total: 4m 5s	remaining: 1m 14s
# 92:	learn: 0.2262938	total: 4m 7s	remaining: 1m 11s
# 93:	learn: 0.2245429	total: 4m 10s	remaining: 1m 9s
# 94:	learn: 0.2226587	total: 4m 12s	remaining: 1m 6s
# 95:	learn: 0.2208026	total: 4m 14s	remaining: 1m 3s
# 96:	learn: 0.2191157	total: 4m 17s	remaining: 1m 1s
# 97:	learn: 0.2173485	total: 4m 19s	remaining: 58.3s
# 98:	learn: 0.2154800	total: 4m 22s	remaining: 55.6s
# 99:	learn: 0.2137454	total: 4m 24s	remaining: 52.9s
# 100:	learn: 0.2119628	total: 4m 27s	remaining: 50.3s
# 101:	learn: 0.2102013	total: 4m 29s	remaining: 47.6s
# 102:	learn: 0.2084540	total: 4m 32s	remaining: 44.9s
# 103:	learn: 0.2067511	total: 4m 34s	remaining: 42.3s
# 104:	learn: 0.2050153	total: 4m 37s	remaining: 39.6s
# 105:	learn: 0.2033375	total: 4m 39s	remaining: 36.9s
# 106:	learn: 0.2016829	total: 4m 41s	remaining: 34.3s
# 107:	learn: 0.2000141	total: 4m 44s	remaining: 31.6s
# 108:	learn: 0.1984240	total: 4m 46s	remaining: 29s
# 109:	learn: 0.1968107	total: 4m 49s	remaining: 26.3s
# 110:	learn: 0.1952732	total: 4m 51s	remaining: 23.7s
# 111:	learn: 0.1936691	total: 4m 54s	remaining: 21s
# 112:	learn: 0.1920406	total: 4m 56s	remaining: 18.4s
# 113:	learn: 0.1906138	total: 4m 59s	remaining: 15.8s
# 114:	learn: 0.1890987	total: 5m 1s	remaining: 13.1s
# 115:	learn: 0.1875241	total: 5m 4s	remaining: 10.5s
# 116:	learn: 0.1859258	total: 5m 6s	remaining: 7.86s
# 117:	learn: 0.1845474	total: 5m 9s	remaining: 5.24s
# 118:	learn: 0.1830512	total: 5m 11s	remaining: 2.62s
# 119:	learn: 0.1815594	total: 5m 14s	remaining: 0us
# 0:	learn: 0.4918744	total: 2.58s	remaining: 5m 6s
# 1:	learn: 0.4875337	total: 4.96s	remaining: 4m 52s
# 2:	learn: 0.4833221	total: 7.39s	remaining: 4m 48s
# 3:	learn: 0.4791359	total: 9.79s	remaining: 4m 43s
# 4:	learn: 0.4750470	total: 12.2s	remaining: 4m 40s
# 5:	learn: 0.4707647	total: 14.6s	remaining: 4m 37s
# 6:	learn: 0.4666080	total: 17s	remaining: 4m 34s
# 7:	learn: 0.4625541	total: 19.3s	remaining: 4m 30s
# 8:	learn: 0.4585417	total: 21.7s	remaining: 4m 27s
# 9:	learn: 0.4545528	total: 24.2s	remaining: 4m 25s
# 10:	learn: 0.4505181	total: 26.5s	remaining: 4m 22s
# 11:	learn: 0.4465885	total: 28.9s	remaining: 4m 20s
# 12:	learn: 0.4426889	total: 31.3s	remaining: 4m 17s
# 13:	learn: 0.4387600	total: 33.7s	remaining: 4m 15s
# 14:	learn: 0.4350436	total: 36.1s	remaining: 4m 12s
# 15:	learn: 0.4312958	total: 38.5s	remaining: 4m 10s
# 16:	learn: 0.4277463	total: 40.9s	remaining: 4m 7s
# 17:	learn: 0.4239842	total: 43.3s	remaining: 4m 5s
# 18:	learn: 0.4203272	total: 45.7s	remaining: 4m 2s
# 19:	learn: 0.4166739	total: 48.1s	remaining: 4m
# 20:	learn: 0.4130562	total: 50.5s	remaining: 3m 57s
# 21:	learn: 0.4094214	total: 52.9s	remaining: 3m 55s
# 22:	learn: 0.4059141	total: 55.2s	remaining: 3m 52s
# 23:	learn: 0.4023755	total: 57.6s	remaining: 3m 50s
# 24:	learn: 0.3988996	total: 60s	remaining: 3m 47s
# 25:	learn: 0.3953450	total: 1m 2s	remaining: 3m 45s
# 26:	learn: 0.3918560	total: 1m 4s	remaining: 3m 43s
# 27:	learn: 0.3885579	total: 1m 7s	remaining: 3m 40s
# 28:	learn: 0.3852963	total: 1m 9s	remaining: 3m 38s
# 29:	learn: 0.3819436	total: 1m 11s	remaining: 3m 35s
# 30:	learn: 0.3786966	total: 1m 14s	remaining: 3m 33s
# 31:	learn: 0.3753799	total: 1m 16s	remaining: 3m 31s
# 32:	learn: 0.3721880	total: 1m 19s	remaining: 3m 30s
# 33:	learn: 0.3688981	total: 1m 23s	remaining: 3m 30s
# 34:	learn: 0.3656832	total: 1m 25s	remaining: 3m 28s
# 35:	learn: 0.3625921	total: 1m 28s	remaining: 3m 25s
# 36:	learn: 0.3594621	total: 1m 30s	remaining: 3m 23s
# 37:	learn: 0.3563109	total: 1m 32s	remaining: 3m 20s
# 38:	learn: 0.3531990	total: 1m 35s	remaining: 3m 17s
# 39:	learn: 0.3502752	total: 1m 37s	remaining: 3m 15s
# 40:	learn: 0.3474052	total: 1m 40s	remaining: 3m 12s
# 41:	learn: 0.3444768	total: 1m 42s	remaining: 3m 10s
# 42:	learn: 0.3416826	total: 1m 44s	remaining: 3m 7s
# 43:	learn: 0.3388188	total: 1m 47s	remaining: 3m 5s
# 44:	learn: 0.3360290	total: 1m 49s	remaining: 3m 2s
# 45:	learn: 0.3331748	total: 1m 52s	remaining: 3m
# 46:	learn: 0.3302768	total: 1m 54s	remaining: 2m 57s
# 47:	learn: 0.3274086	total: 1m 56s	remaining: 2m 55s
# 48:	learn: 0.3245844	total: 1m 59s	remaining: 2m 52s
# 49:	learn: 0.3219010	total: 2m 1s	remaining: 2m 50s
# 50:	learn: 0.3191193	total: 2m 4s	remaining: 2m 47s
# 51:	learn: 0.3164357	total: 2m 6s	remaining: 2m 45s
# 52:	learn: 0.3139395	total: 2m 8s	remaining: 2m 42s
# 53:	learn: 0.3113667	total: 2m 11s	remaining: 2m 40s
# 54:	learn: 0.3086910	total: 2m 13s	remaining: 2m 38s
# 55:	learn: 0.3061567	total: 2m 16s	remaining: 2m 35s
# 56:	learn: 0.3035547	total: 2m 18s	remaining: 2m 33s
# 57:	learn: 0.3009282	total: 2m 20s	remaining: 2m 30s
# 58:	learn: 0.2983871	total: 2m 23s	remaining: 2m 28s
# 59:	learn: 0.2959155	total: 2m 25s	remaining: 2m 25s
# 60:	learn: 0.2935475	total: 2m 28s	remaining: 2m 23s
# 61:	learn: 0.2913546	total: 2m 30s	remaining: 2m 20s
# 62:	learn: 0.2889030	total: 2m 32s	remaining: 2m 18s
# 63:	learn: 0.2864234	total: 2m 35s	remaining: 2m 15s
# 64:	learn: 0.2839303	total: 2m 37s	remaining: 2m 13s
# 65:	learn: 0.2814877	total: 2m 40s	remaining: 2m 11s
# 66:	learn: 0.2790956	total: 2m 42s	remaining: 2m 8s
# 67:	learn: 0.2768113	total: 2m 44s	remaining: 2m 6s
# 68:	learn: 0.2746485	total: 2m 47s	remaining: 2m 3s
# 69:	learn: 0.2723381	total: 2m 49s	remaining: 2m 1s
# 70:	learn: 0.2701523	total: 2m 52s	remaining: 1m 58s
# 71:	learn: 0.2679063	total: 2m 54s	remaining: 1m 56s
# 72:	learn: 0.2658242	total: 2m 57s	remaining: 1m 53s
# 73:	learn: 0.2635752	total: 2m 59s	remaining: 1m 51s
# 74:	learn: 0.2612957	total: 3m 1s	remaining: 1m 49s
# 75:	learn: 0.2591488	total: 3m 4s	remaining: 1m 46s
# 76:	learn: 0.2570733	total: 3m 6s	remaining: 1m 44s
# 77:	learn: 0.2550854	total: 3m 9s	remaining: 1m 41s
# 78:	learn: 0.2528966	total: 3m 11s	remaining: 1m 39s
# 79:	learn: 0.2508115	total: 3m 13s	remaining: 1m 36s
# 80:	learn: 0.2488357	total: 3m 16s	remaining: 1m 34s
# 81:	learn: 0.2466844	total: 3m 18s	remaining: 1m 32s
# 82:	learn: 0.2445678	total: 3m 21s	remaining: 1m 29s
# 83:	learn: 0.2426134	total: 3m 23s	remaining: 1m 27s
# 84:	learn: 0.2406535	total: 3m 30s	remaining: 1m 26s
# 85:	learn: 0.2387226	total: 3m 38s	remaining: 1m 26s
# 86:	learn: 0.2367804	total: 3m 40s	remaining: 1m 23s
# 87:	learn: 0.2348724	total: 3m 44s	remaining: 1m 21s
# 88:	learn: 0.2330541	total: 3m 47s	remaining: 1m 19s
# 89:	learn: 0.2310642	total: 3m 49s	remaining: 1m 16s
# 90:	learn: 0.2291529	total: 3m 52s	remaining: 1m 13s
# 91:	learn: 0.2272786	total: 3m 54s	remaining: 1m 11s
# 92:	learn: 0.2254190	total: 3m 56s	remaining: 1m 8s
# 93:	learn: 0.2236753	total: 3m 59s	remaining: 1m 6s
# 94:	learn: 0.2219023	total: 4m 1s	remaining: 1m 3s
# 95:	learn: 0.2200382	total: 4m 4s	remaining: 1m 1s
# 96:	learn: 0.2182549	total: 4m 6s	remaining: 58.5s
# 97:	learn: 0.2164326	total: 4m 9s	remaining: 55.9s
# 98:	learn: 0.2146313	total: 4m 11s	remaining: 53.4s
# 99:	learn: 0.2129425	total: 4m 14s	remaining: 50.8s
# 100:	learn: 0.2111302	total: 4m 16s	remaining: 48.3s
# 101:	learn: 0.2095078	total: 4m 19s	remaining: 45.7s
# 102:	learn: 0.2078363	total: 4m 21s	remaining: 43.2s
# 103:	learn: 0.2062373	total: 4m 23s	remaining: 40.6s
# 104:	learn: 0.2045837	total: 4m 26s	remaining: 38.1s
# 105:	learn: 0.2029456	total: 4m 28s	remaining: 35.5s
# 106:	learn: 0.2012806	total: 4m 31s	remaining: 33s
# 107:	learn: 0.1996669	total: 4m 33s	remaining: 30.4s
# 108:	learn: 0.1980644	total: 4m 36s	remaining: 27.9s
# 109:	learn: 0.1964418	total: 4m 38s	remaining: 25.3s
# 110:	learn: 0.1949184	total: 4m 41s	remaining: 22.8s
# 111:	learn: 0.1933833	total: 4m 43s	remaining: 20.3s
# 112:	learn: 0.1918836	total: 4m 46s	remaining: 17.7s
# 113:	learn: 0.1903000	total: 4m 48s	remaining: 15.2s
# 114:	learn: 0.1888136	total: 4m 51s	remaining: 12.7s
# 115:	learn: 0.1872519	total: 4m 53s	remaining: 10.1s
# 116:	learn: 0.1857792	total: 4m 56s	remaining: 7.59s
# 117:	learn: 0.1842416	total: 4m 58s	remaining: 5.06s
# 118:	learn: 0.1827523	total: 5m 1s	remaining: 2.53s
# 119:	learn: 0.1812254	total: 5m 3s	remaining: 0us
# 0:	learn: 0.4927462	total: 2.5s	remaining: 4m 57s
# 1:	learn: 0.4884922	total: 4.99s	remaining: 4m 54s
# 2:	learn: 0.4841571	total: 7.49s	remaining: 4m 52s
# 3:	learn: 0.4799007	total: 9.97s	remaining: 4m 49s
# 4:	learn: 0.4757140	total: 12.5s	remaining: 4m 48s
# 5:	learn: 0.4715207	total: 15.1s	remaining: 4m 46s
# 6:	learn: 0.4675730	total: 17.6s	remaining: 4m 43s
# 7:	learn: 0.4636761	total: 20s	remaining: 4m 39s
# 8:	learn: 0.4597180	total: 22.4s	remaining: 4m 36s
# 9:	learn: 0.4556865	total: 24.9s	remaining: 4m 34s
# 10:	learn: 0.4516790	total: 27.4s	remaining: 4m 31s
# 11:	learn: 0.4478335	total: 29.9s	remaining: 4m 29s
# 12:	learn: 0.4442089	total: 32.4s	remaining: 4m 26s
# 13:	learn: 0.4402536	total: 34.8s	remaining: 4m 23s
# 14:	learn: 0.4364988	total: 37.3s	remaining: 4m 21s
# 15:	learn: 0.4329127	total: 39.8s	remaining: 4m 18s
# 16:	learn: 0.4291811	total: 42.2s	remaining: 4m 15s
# 17:	learn: 0.4253484	total: 44.7s	remaining: 4m 13s
# 18:	learn: 0.4216226	total: 47.2s	remaining: 4m 10s
# 19:	learn: 0.4179233	total: 49.6s	remaining: 4m 8s
# 20:	learn: 0.4145124	total: 52.1s	remaining: 4m 5s
# 21:	learn: 0.4109423	total: 54.6s	remaining: 4m 3s
# 22:	learn: 0.4073436	total: 57s	remaining: 4m
# 23:	learn: 0.4037095	total: 59.4s	remaining: 3m 57s
# 24:	learn: 0.4002653	total: 1m 1s	remaining: 3m 55s
# 25:	learn: 0.3966896	total: 1m 4s	remaining: 3m 52s
# 26:	learn: 0.3933277	total: 1m 6s	remaining: 3m 50s
# 27:	learn: 0.3900534	total: 1m 9s	remaining: 3m 47s
# 28:	learn: 0.3867537	total: 1m 11s	remaining: 3m 45s
# 29:	learn: 0.3834510	total: 1m 14s	remaining: 3m 42s
# 30:	learn: 0.3802138	total: 1m 16s	remaining: 3m 40s
# 31:	learn: 0.3768754	total: 1m 19s	remaining: 3m 38s
# 32:	learn: 0.3737328	total: 1m 21s	remaining: 3m 35s
# 33:	learn: 0.3704299	total: 1m 24s	remaining: 3m 33s
# 34:	learn: 0.3672346	total: 1m 26s	remaining: 3m 30s
# 35:	learn: 0.3640997	total: 1m 29s	remaining: 3m 28s
# 36:	learn: 0.3611718	total: 1m 32s	remaining: 3m 26s
# 37:	learn: 0.3580435	total: 1m 35s	remaining: 3m 26s
# 38:	learn: 0.3550303	total: 1m 38s	remaining: 3m 23s
# 39:	learn: 0.3520646	total: 1m 40s	remaining: 3m 21s
# 40:	learn: 0.3491796	total: 1m 43s	remaining: 3m 18s
# 41:	learn: 0.3462553	total: 1m 45s	remaining: 3m 16s
# 42:	learn: 0.3434368	total: 1m 48s	remaining: 3m 13s
# 43:	learn: 0.3406197	total: 1m 50s	remaining: 3m 11s
# 44:	learn: 0.3376819	total: 1m 53s	remaining: 3m 8s
# 45:	learn: 0.3349411	total: 1m 55s	remaining: 3m 5s
# 46:	learn: 0.3321398	total: 1m 57s	remaining: 3m 3s
# 47:	learn: 0.3293059	total: 2m	remaining: 3m
# 48:	learn: 0.3265117	total: 2m 2s	remaining: 2m 57s
# 49:	learn: 0.3236853	total: 2m 5s	remaining: 2m 55s
# 50:	learn: 0.3210508	total: 2m 7s	remaining: 2m 52s
# 51:	learn: 0.3182627	total: 2m 10s	remaining: 2m 50s
# 52:	learn: 0.3157190	total: 2m 12s	remaining: 2m 47s
# 53:	learn: 0.3130292	total: 2m 15s	remaining: 2m 45s
# 54:	learn: 0.3103611	total: 2m 17s	remaining: 2m 42s
# 55:	learn: 0.3076703	total: 2m 20s	remaining: 2m 40s
# 56:	learn: 0.3052342	total: 2m 22s	remaining: 2m 37s
# 57:	learn: 0.3026280	total: 2m 25s	remaining: 2m 35s
# 58:	learn: 0.3000644	total: 2m 27s	remaining: 2m 32s
# 59:	learn: 0.2975104	total: 2m 29s	remaining: 2m 29s
# 60:	learn: 0.2950392	total: 2m 32s	remaining: 2m 27s
# 61:	learn: 0.2926465	total: 2m 34s	remaining: 2m 24s
# 62:	learn: 0.2903358	total: 2m 37s	remaining: 2m 22s
# 63:	learn: 0.2878433	total: 2m 39s	remaining: 2m 19s
# 64:	learn: 0.2854660	total: 2m 42s	remaining: 2m 17s
# 65:	learn: 0.2830520	total: 2m 44s	remaining: 2m 14s
# 66:	learn: 0.2806974	total: 2m 47s	remaining: 2m 12s
# 67:	learn: 0.2785026	total: 2m 49s	remaining: 2m 9s
# 68:	learn: 0.2761822	total: 2m 52s	remaining: 2m 7s
# 69:	learn: 0.2739302	total: 2m 54s	remaining: 2m 4s
# 70:	learn: 0.2716847	total: 2m 57s	remaining: 2m 2s
# 71:	learn: 0.2693870	total: 2m 59s	remaining: 1m 59s
# 72:	learn: 0.2671007	total: 3m 2s	remaining: 1m 57s
# 73:	learn: 0.2648543	total: 3m 4s	remaining: 1m 54s
# 74:	learn: 0.2626685	total: 3m 6s	remaining: 1m 52s
# 75:	learn: 0.2604998	total: 3m 9s	remaining: 1m 49s
# 76:	learn: 0.2583190	total: 3m 11s	remaining: 1m 47s
# 77:	learn: 0.2562284	total: 3m 14s	remaining: 1m 44s
# 78:	learn: 0.2540594	total: 3m 16s	remaining: 1m 42s
# 79:	learn: 0.2518772	total: 3m 19s	remaining: 1m 39s
# 80:	learn: 0.2498206	total: 3m 21s	remaining: 1m 37s
# 81:	learn: 0.2477541	total: 3m 24s	remaining: 1m 34s
# 82:	learn: 0.2456858	total: 3m 26s	remaining: 1m 32s
# 83:	learn: 0.2435541	total: 3m 29s	remaining: 1m 29s
# 84:	learn: 0.2415965	total: 3m 31s	remaining: 1m 27s
# 85:	learn: 0.2396298	total: 3m 34s	remaining: 1m 24s
# 86:	learn: 0.2377525	total: 3m 36s	remaining: 1m 22s
# 87:	learn: 0.2357529	total: 3m 39s	remaining: 1m 19s
# 88:	learn: 0.2338756	total: 3m 41s	remaining: 1m 17s
# 89:	learn: 0.2319068	total: 3m 43s	remaining: 1m 14s
# 90:	learn: 0.2300525	total: 3m 46s	remaining: 1m 12s
# 91:	learn: 0.2281665	total: 3m 48s	remaining: 1m 9s
# 92:	learn: 0.2263979	total: 3m 51s	remaining: 1m 7s
# 93:	learn: 0.2246366	total: 3m 53s	remaining: 1m 4s
# 94:	learn: 0.2227199	total: 3m 58s	remaining: 1m 2s
# 95:	learn: 0.2208530	total: 4m	remaining: 1m
# 96:	learn: 0.2190646	total: 4m 2s	remaining: 57.6s
# 97:	learn: 0.2172927	total: 4m 5s	remaining: 55.1s
# 98:	learn: 0.2154784	total: 4m 8s	remaining: 52.7s
# 99:	learn: 0.2137235	total: 4m 11s	remaining: 50.2s
# 100:	learn: 0.2119619	total: 4m 13s	remaining: 47.8s
# 101:	learn: 0.2102918	total: 4m 16s	remaining: 45.3s
# 102:	learn: 0.2085999	total: 4m 19s	remaining: 42.8s
# 103:	learn: 0.2068779	total: 4m 22s	remaining: 40.3s
# 104:	learn: 0.2051668	total: 4m 24s	remaining: 37.8s
# 105:	learn: 0.2035399	total: 4m 27s	remaining: 35.3s
# 106:	learn: 0.2019138	total: 4m 29s	remaining: 32.8s
# 107:	learn: 0.2003477	total: 4m 32s	remaining: 30.2s
# 108:	learn: 0.1986657	total: 4m 34s	remaining: 27.7s
# 109:	learn: 0.1969745	total: 4m 37s	remaining: 25.2s
# 110:	learn: 0.1953934	total: 4m 39s	remaining: 22.7s
# 111:	learn: 0.1938501	total: 4m 42s	remaining: 20.1s
# 112:	learn: 0.1922611	total: 4m 44s	remaining: 17.6s
# 113:	learn: 0.1906458	total: 4m 47s	remaining: 15.1s
# 114:	learn: 0.1891378	total: 4m 49s	remaining: 12.6s
# 115:	learn: 0.1875394	total: 4m 51s	remaining: 10.1s
# 116:	learn: 0.1859514	total: 4m 54s	remaining: 7.55s
# 117:	learn: 0.1844453	total: 4m 56s	remaining: 5.03s
# 118:	learn: 0.1829951	total: 4m 59s	remaining: 2.52s
# 119:	learn: 0.1815370	total: 5m 2s	remaining: 0us
# 0:	learn: 0.4921164	total: 3.21s	remaining: 6m 22s
# 1:	learn: 0.4879710	total: 5.96s	remaining: 5m 51s
# 2:	learn: 0.4838849	total: 8.76s	remaining: 5m 41s
# 3:	learn: 0.4796615	total: 11.6s	remaining: 5m 35s
# 4:	learn: 0.4755275	total: 14.2s	remaining: 5m 27s
# 5:	learn: 0.4713903	total: 16.9s	remaining: 5m 20s
# 6:	learn: 0.4674664	total: 19.5s	remaining: 5m 15s
# 7:	learn: 0.4637171	total: 22.1s	remaining: 5m 8s
# 8:	learn: 0.4597591	total: 24.7s	remaining: 5m 4s
# 9:	learn: 0.4560770	total: 27.4s	remaining: 5m 1s
# 10:	learn: 0.4521413	total: 30s	remaining: 4m 57s
# 11:	learn: 0.4483744	total: 32.7s	remaining: 4m 54s
# 12:	learn: 0.4446458	total: 35.3s	remaining: 4m 50s
# 13:	learn: 0.4409113	total: 37.9s	remaining: 4m 47s
# 14:	learn: 0.4373726	total: 40.6s	remaining: 4m 44s
# 15:	learn: 0.4336968	total: 43.3s	remaining: 4m 41s
# 16:	learn: 0.4301878	total: 45.9s	remaining: 4m 38s
# 17:	learn: 0.4266574	total: 48.6s	remaining: 4m 35s
# 18:	learn: 0.4231071	total: 51.2s	remaining: 4m 32s
# 19:	learn: 0.4196192	total: 53.9s	remaining: 4m 29s
# 20:	learn: 0.4160912	total: 56.6s	remaining: 4m 26s
# 21:	learn: 0.4127603	total: 59.3s	remaining: 4m 24s
# 22:	learn: 0.4093550	total: 1m 2s	remaining: 4m 22s
# 23:	learn: 0.4060728	total: 1m 6s	remaining: 4m 24s
# 24:	learn: 0.4026946	total: 1m 8s	remaining: 4m 21s
# 25:	learn: 0.3994078	total: 1m 11s	remaining: 4m 18s
# 26:	learn: 0.3960727	total: 1m 14s	remaining: 4m 16s
# 27:	learn: 0.3927414	total: 1m 17s	remaining: 4m 13s
# 28:	learn: 0.3894214	total: 1m 19s	remaining: 4m 10s
# 29:	learn: 0.3861263	total: 1m 22s	remaining: 4m 7s
# 30:	learn: 0.3828892	total: 1m 25s	remaining: 4m 4s
# 31:	learn: 0.3797302	total: 1m 28s	remaining: 4m 2s
# 32:	learn: 0.3766706	total: 1m 31s	remaining: 3m 59s
# 33:	learn: 0.3737411	total: 1m 33s	remaining: 3m 56s
# 34:	learn: 0.3706800	total: 1m 36s	remaining: 3m 54s
# 35:	learn: 0.3676951	total: 1m 39s	remaining: 3m 51s
# 36:	learn: 0.3645792	total: 1m 42s	remaining: 3m 48s
# 37:	learn: 0.3615166	total: 1m 44s	remaining: 3m 46s
# 38:	learn: 0.3585644	total: 1m 47s	remaining: 3m 43s
# 39:	learn: 0.3555141	total: 1m 50s	remaining: 3m 40s
# 40:	learn: 0.3524848	total: 1m 53s	remaining: 3m 37s
# 41:	learn: 0.3497286	total: 1m 55s	remaining: 3m 34s
# 42:	learn: 0.3469032	total: 1m 58s	remaining: 3m 31s
# 43:	learn: 0.3439662	total: 2m	remaining: 3m 28s
# 44:	learn: 0.3412271	total: 2m 3s	remaining: 3m 26s
# 45:	learn: 0.3386282	total: 2m 6s	remaining: 3m 23s
# 46:	learn: 0.3361245	total: 2m 9s	remaining: 3m 20s
# 47:	learn: 0.3333718	total: 2m 11s	remaining: 3m 17s
# 48:	learn: 0.3307873	total: 2m 14s	remaining: 3m 15s
# 49:	learn: 0.3280735	total: 2m 17s	remaining: 3m 12s
# 50:	learn: 0.3253422	total: 2m 20s	remaining: 3m 10s
# 51:	learn: 0.3228388	total: 2m 23s	remaining: 3m 7s
# 52:	learn: 0.3202622	total: 2m 26s	remaining: 3m 5s
# 53:	learn: 0.3177591	total: 2m 29s	remaining: 3m 2s
# 54:	learn: 0.3151030	total: 2m 32s	remaining: 2m 59s
# 55:	learn: 0.3125553	total: 2m 35s	remaining: 2m 57s
# 56:	learn: 0.3099791	total: 2m 37s	remaining: 2m 54s
# 57:	learn: 0.3074396	total: 2m 40s	remaining: 2m 51s
# 58:	learn: 0.3050904	total: 2m 43s	remaining: 2m 48s
# 59:	learn: 0.3027089	total: 2m 45s	remaining: 2m 45s
# 60:	learn: 0.3002980	total: 2m 48s	remaining: 2m 43s
# 61:	learn: 0.2979552	total: 2m 51s	remaining: 2m 40s
# 62:	learn: 0.2955410	total: 2m 54s	remaining: 2m 37s
# 63:	learn: 0.2932038	total: 2m 56s	remaining: 2m 34s
# 64:	learn: 0.2909479	total: 2m 59s	remaining: 2m 31s
# 65:	learn: 0.2886051	total: 3m 2s	remaining: 2m 29s
# 66:	learn: 0.2862443	total: 3m 5s	remaining: 2m 26s
# 67:	learn: 0.2839616	total: 3m 7s	remaining: 2m 23s
# 68:	learn: 0.2816223	total: 3m 10s	remaining: 2m 20s
# 69:	learn: 0.2793587	total: 3m 13s	remaining: 2m 18s
# 70:	learn: 0.2770527	total: 3m 15s	remaining: 2m 15s
# 71:	learn: 0.2749401	total: 3m 18s	remaining: 2m 12s
# 72:	learn: 0.2728192	total: 3m 21s	remaining: 2m 9s
# 73:	learn: 0.2706475	total: 3m 23s	remaining: 2m 6s
# 74:	learn: 0.2686833	total: 3m 27s	remaining: 2m 4s
# 75:	learn: 0.2666132	total: 3m 31s	remaining: 2m 2s
# 76:	learn: 0.2646049	total: 3m 33s	remaining: 1m 59s
# 77:	learn: 0.2625792	total: 3m 36s	remaining: 1m 56s
# 78:	learn: 0.2605749	total: 3m 39s	remaining: 1m 53s
# 79:	learn: 0.2584127	total: 3m 41s	remaining: 1m 50s
# 80:	learn: 0.2563807	total: 3m 44s	remaining: 1m 48s
# 81:	learn: 0.2543440	total: 3m 47s	remaining: 1m 45s
# 82:	learn: 0.2523397	total: 3m 49s	remaining: 1m 42s
# 83:	learn: 0.2503406	total: 3m 52s	remaining: 1m 39s
# 84:	learn: 0.2483346	total: 3m 55s	remaining: 1m 36s
# 85:	learn: 0.2463527	total: 3m 57s	remaining: 1m 33s
# 86:	learn: 0.2443896	total: 4m	remaining: 1m 31s
# 87:	learn: 0.2424918	total: 4m 2s	remaining: 1m 28s
# 88:	learn: 0.2406716	total: 4m 5s	remaining: 1m 25s
# 89:	learn: 0.2388313	total: 4m 7s	remaining: 1m 22s
# 90:	learn: 0.2369421	total: 4m 10s	remaining: 1m 19s
# 91:	learn: 0.2350000	total: 4m 13s	remaining: 1m 17s
# 92:	learn: 0.2330606	total: 4m 15s	remaining: 1m 14s
# 93:	learn: 0.2312539	total: 4m 18s	remaining: 1m 11s
# 94:	learn: 0.2294140	total: 4m 21s	remaining: 1m 8s
# 95:	learn: 0.2276140	total: 4m 23s	remaining: 1m 5s
# 96:	learn: 0.2260097	total: 4m 26s	remaining: 1m 3s
# 97:	learn: 0.2243594	total: 4m 28s	remaining: 1m
# 98:	learn: 0.2226804	total: 4m 31s	remaining: 57.6s
# 99:	learn: 0.2209670	total: 4m 34s	remaining: 54.8s
# 100:	learn: 0.2192794	total: 4m 36s	remaining: 52.1s
# 101:	learn: 0.2176541	total: 4m 39s	remaining: 49.3s
# 102:	learn: 0.2160609	total: 4m 42s	remaining: 46.6s
# 103:	learn: 0.2144051	total: 4m 44s	remaining: 43.8s
# 104:	learn: 0.2127227	total: 4m 47s	remaining: 41s
# 105:	learn: 0.2110621	total: 4m 49s	remaining: 38.3s
# 106:	learn: 0.2095068	total: 4m 52s	remaining: 35.5s
# 107:	learn: 0.2079201	total: 4m 55s	remaining: 32.8s
# 108:	learn: 0.2062633	total: 4m 57s	remaining: 30s
# 109:	learn: 0.2047342	total: 5m	remaining: 27.3s
# 110:	learn: 0.2032593	total: 5m 3s	remaining: 24.6s
# 111:	learn: 0.2016736	total: 5m 5s	remaining: 21.8s
# 112:	learn: 0.2000940	total: 5m 8s	remaining: 19.1s
# 113:	learn: 0.1985258	total: 5m 10s	remaining: 16.4s
# 114:	learn: 0.1971020	total: 5m 13s	remaining: 13.6s
# 115:	learn: 0.1955946	total: 5m 16s	remaining: 10.9s
# 116:	learn: 0.1940879	total: 5m 18s	remaining: 8.18s
# 117:	learn: 0.1926738	total: 5m 21s	remaining: 5.45s
# 118:	learn: 0.1912460	total: 5m 24s	remaining: 2.72s
# 119:	learn: 0.1897531	total: 5m 26s	remaining: 0us
#       accuracy  precision    recall  f1-score   roc_auc       mae  train_acc
# fold
# 1     0.786496   0.785531  0.852450  0.817623  0.875918  0.299258        NaN
# 2     0.790247   0.774872  0.866896  0.818305  0.880087  0.301673        NaN
# 3     0.780556   0.770739  0.861720  0.813694  0.872539  0.306593        NaN
# 4     0.790247   0.798272  0.851491  0.824023  0.872067  0.300881        NaN
# mean  0.786887   0.782354  0.858139  0.818411  0.875153  0.302101        1.0

# %%
from sklearn.impute import SimpleImputer


test_df = evaluator.preprocess(test_df)

# handle nan values
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp = imp.fit(test_df)
test_df = pd.DataFrame(
  imp.transform(test_df),
  columns=test_df.columns
)

preds = evaluator.model.predict(test_df)
submission_df["nerdiness"] = preds

submission_df.to_csv("submission/2022-08-17_ENSEMBLE_v0_1.csv", index=False)

# %% [markdown]
# ## Modularization

# %%
from evaluator.evaluator import Model, Evaluator, Optimizer
from sklearn.ensemble import VotingRegressor

class MyEvaluator(Evaluator):
  def __init__(self, *args, **kwargs):
    super().__init__(*args, **kwargs)

class MyModel(Model):
  def __init__(self, *args, **kwargs):
    super().__init__(*args, **kwargs)

  def optimize(self, initial_params, **kwargs):
    self.optimizer = MyOptimizer(
        self.train_df, 
        initial_params, 
        self.model_name,
        self.model_type,
    )
    best_params = self.optimizer.run(**kwargs)
    self.__init__(self.train_df, self.model_name, self.model_type, **best_params)

class MyOptimizer(Optimizer):
  def __init__(self, *args, **kwargs):
    super().__init__(*args, **kwargs)

  def objective(self, trial):
    ## Tuning Parmeters
    for param, dtype, value in self.initial_params:
      if dtype == "static":
        self.params[param] = value
      elif dtype == "int":
        self.params[param] = trial.suggest_int(param, *value)
      elif dtype == "float":
        self.params[param] = trial.suggest_uniform(param, *value)
      elif dtype == "log":
        self.params[param] = trial.suggest_loguniform(param, *value)
      elif dtype == "categorical":
        self.params[param] = trial.suggest_categorical(param, value)
      else:
        raise NameError("dtype must be one of ('static', 'int', 'float', 'log', 'categorical')")

    ## Objective Metric
    result_df = MyEvaluator(
        **MyModel(self.train_df, self.model_name, self.model_type, **self.params).get_model()
    ).run(train_acc=False)

    return result_df["roc_auc"]["mean"]

# %%
import yaml

with open('evaluator/best_models_config.yaml') as f:
  model_config = yaml.load(f, Loader=yaml.FullLoader)

# %%
model_config
# Out:
# {'lgbm': [{'name': 'LightGBM',
#    'type': 'rgr',
#    'best_score': 0.880712,
#    'best_params': {'objective': 'binary',
#     'metric': 'auc',
#     'n_estimators': 500,
#     'learning_rate': 0.026332779906149555,
#     'num_leaves': 955,
#     'reg_alpha': 6.90331310095056e-08,
#     'reg_lambda': 2.30837413695962e-06,
#     'feature_fraction': 0.4,
#     'bagging_fraction': 0.8823839979334422,
#     'bagging_freq': 5,
#     'min_child_samples': 5}}],
#  'xgb': [{'name': 'XGBoost',
#    'type': 'rgr',
#    'best_score': 0.869358,
#    'best_params': {'objective': 'reg:squarederror',
#     'average': 'micro',
#     'n_estimators': 746,
#     'learning_rate': 0.0181863245309935,
#     'gamma': 0,
#     'max_depth': 11,
#     'lambda': 1,
#     'alpha': 4,
#     'subsample': 0.7231465475519483}}],
#  'cat': [{'name': 'CatBoost',
#    'type': 'rgr',
#    'best_score': 0.86791,
#    'best_params': {'learning_rate': 0.01001831305173243,
#     'bagging_temperature': 5.20036760425302,
#     'n_estimators': 120,
#     'max_depth': 16,
#     'random_strength': 0,
#     'colsample_bylevel': 0.984260923537832,
#     'l2_leaf_reg': 1.0732827610812122e-05,
#     'min_child_samples': 100,
#     'max_bin': 302,
#     'od_type': 'Iter'}}],
#  'rf': [{'name': 'RandomForest',
#    'type': 'clf',
#    'best_score': 0.866943,
#    'best_params': {}}],
#  'et': [{'name': 'ExtraTrees',
#    'type': 'clf',
#    'best_score': 0.871722,
#    'best_params': {'n_estimators': 292,
#     'max_depth': 45,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'max_features': 0.729627795893577}}]}

# %%
from sklearn.ensemble import VotingRegressor

class VotingModel(VotingRegressor):
  def __init__(self, model_types, estimators):
    self.model_types = model_types
    super().__init__(estimators)

  def _validate_estimators(self):
      if self.estimators is None or len(self.estimators) == 0:
          raise ValueError(
              "Invalid 'estimators' attribute, 'estimators' should be a list"
              " of (string, estimator) tuples."
          )
      names, estimators = zip(*self.estimators)
      # defined by MetaEstimatorMixin
      self._validate_names(names)

      has_estimator = any(est != "drop" for est in estimators)
      if not has_estimator:
          raise ValueError(
              "All estimators are dropped. At least one is required "
              "to be an estimator."
          )

      return names, estimators

  def predict(self, X):
    return np.average(
      np.asarray([
        est.predict(X) if model_type=="rgr" else est.predict_proba(X)[:,1]
        for model_type, est in zip(self.model_types, self.estimators_)
      ]).T, 
      axis=1, 
      weights=self._weights_not_none
    )

# %%
import yaml

class EnsembleModel():
  def __init__(
    self, 
    train_df,
    models=["lgbm", "xgb", "cat", "rf", "et"]
  ):
    with open('evaluator/best_models_config.yaml') as f:
      model_configs = yaml.load(f, Loader=yaml.FullLoader)

    self.train_df = train_df

    estimators = []
    model_types = []
    for model_name in models:
        configs = model_configs[model_name][0]
        model_type = configs["type"]
        params = configs["best_params"]
        
        estimators.append((
            model_name, 
            Model(train_df, model_name, model_type, **params).get_model()['model']
        ))
        model_types.append(model_type)

    self.ensemble_model = VotingModel(
        estimators=estimators,
        model_types=model_types,
    )

  def get_model(self):
    return {
        'train_df': self.train_df,
        'model': self.ensemble_model,
        'model_name': 'ensemble',
        'model_type': 'rgr',
    }

# %%
evaluator = Evaluator(
    **EnsembleModel(train_df, models=['lgbm', 'xgb', 'et', 'rf']).get_model()
).run()

# %%
submission_df = evaluator.make_submission(test_df, submission_df)
submission_df.to_csv("submission/2022-08-20_ENSEMBLE_v0_2.csv", index=False)
